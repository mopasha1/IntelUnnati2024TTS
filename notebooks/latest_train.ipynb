# %%
#unzipping the datasets file from drive
# !unzip '/content/drive/MyDrive/generated_plates_final2.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: generated_plates_final/SK34H5276_2.jpg
#   inflating: generated_plates_final/SK34HP2497_1.jpg
#   inflating: generated_plates_final/SK34KD3379_2.jpg
#   inflating: generated_plates_final/SK34L7572_2.jpg
#   inflating: generated_plates_final/SK35B6166_2.jpg
#   inflating: generated_plates_final/SK35FL3913_1.jpg
#   inflating: generated_plates_final/SK35H8624_2.jpg
#   inflating: generated_plates_final/SK35X9138_2.jpg
#   inflating: generated_plates_final/SK36B5826_1.jpg
#   inflating: generated_plates_final/SK36C0884_2.jpg
#   inflating: generated_plates_final/SK36E1406_2.jpg
#   inflating: generated_plates_final/SK36FK7879_2.jpg
#   inflating: generated_plates_final/SK36JB1355_2.jpg
#   inflating: generated_plates_final/SK36KZ8446_2.jpg
#   inflating: generated_plates_final/SK36M0836_2.jpg
#   inflating: generated_plates_final/SK36UW4619_2.jpg
#   inflating: generated_plates_final/SK36W3464_1.jpg
# ...

# %%
# !pip install torch
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
#continuing training from last checkpoint as Google GPU limits expired

# !python '/content/drive/MyDrive/License_Plate_Detection_Pytorch/LPRNet/LPRNet_Train.py' --img_dirs_train '/content/generated_plates_final' --img_dirs_val "/content/generated_plates_final" --epoch 1200 --batch_size 128 --stn_path "/content/2stn_Iter_011700_model.ckpt" --checkpoint "/content/2lprnet_Iter_011700_model.ckpt"
# Out:
# LPRNet loaded
# STN loaded
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# training dataset loaded with length : 26022
# validation dataset loaded with length : 26022
# training kicked off..
# ----------
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:4404: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# ...
