# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.6/793.6 kB 25.9 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall wandb -y
# Out:
# Found existing installation: wandb 0.17.0
# Uninstalling wandb-0.17.0:
#   Successfully uninstalled wandb-0.17.0

# %%
# !yolo task=detect mode=train model="yolov8n.pt" data="/kaggle/input/anprdataset/anpr/data.yaml" epochs=120 imgsz=640 plots=True batch=32
# Out:
# ...
# 100%|███████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 110MB/s]
# Ultralytics YOLOv8.2.45 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...
